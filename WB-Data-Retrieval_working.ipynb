# %%
# Import dependencies
import wbgapi as wb
import pandas as pd

# %%
# Look at help for series (data streams)
help(wb.series)
# Out:
# Help on module wbgapi.series in wbgapi:
#
# NAME
#     wbgapi.series - Access information about series in a database
#
# FUNCTIONS
#     Series(id='all', q=None, topic=None, db=None, name='SeriesName')
#         Return a pandas Series by calling list
#
#     get(id, db=None)
#         Retrieve a specific series object
#
#         Arguments:
#             id:     the series identifier
#
#             db:     database; pass None to access the global database
#
#         Returns:
#             a series object
#
#         Example:
#             print(wbgapi.series.get('SP.POP.TOTL')['value'])
#
#     info(id='all', q=None, topic=None, db=None)
#         Print a user report of series. This can be time consuming
#         for large databases like the WDI if 'all' series are requested.
#
#         Arguments:
#             id:         a series identifier or list-like of identifiers
#
#             q:          search string (on series name))
#
#             topic:      topic ID or list-like
#
#             db:         database; pass None to access the global database
#
#         Returns:
#             None
#
#     list(id='all', q=None, topic=None, db=None)
#         Return a list of series elements in the current database
#
#         Arguments:
#             id:     a series identifier (i.e., CETS code) or list-like
#
#             q:      search string (on series name)
#
#             topic:  topic ID or list-like
#
#             db:     database; pass None to access the global database
#
#         Returns:
#             a generator object
#
#         Example:
#             for elem in wbgapi.series.list():
#                 print(elem['id'], elem['value'])
#
# FILE
#     c:\users\elott\anaconda3\envs\pythondataone\lib\site-packages\wbgapi\series.py

# %%
# creates API call that returns a pandas Series of series (data streams) available in World Bank's World Development Indicators database
series = wb.series.Series()
series
# Out:
# AG.AGR.TRAC.NO                        Agricultural machinery, tractors
# AG.CON.FERT.PT.ZS    Fertilizer consumption (% of fertilizer produc...
# AG.CON.FERT.ZS       Fertilizer consumption (kilograms per hectare ...
# AG.LND.AGRI.K2                              Agricultural land (sq. km)
# AG.LND.AGRI.ZS                      Agricultural land (% of land area)
#                                            ...
# VC.IDP.NWDS          Internally displaced persons, new displacement...
# VC.IDP.TOCV          Internally displaced persons, total displaced ...
# VC.IHR.PSRC.FE.P5    Intentional homicides, female (per 100,000 fem...
# VC.IHR.PSRC.MA.P5       Intentional homicides, male (per 100,000 male)
# VC.IHR.PSRC.P5              Intentional homicides (per 100,000 people)
# Name: SeriesName, Length: 1442, dtype: object

# %%
# turn series(data streams) variable results into a DataFrame
series_df = pd.DataFrame(series)
series_df = series_df.reset_index(level=0)
series_df = series_df.rename(columns={'index':'series_id', 'SeriesName': 'series_name'})
series_df['series_id'] = series_df['series_id'].astype('string')
series_df['series_name'] = series_df['series_name'].astype('string')
series_df.sort_values(by = ['series_id'])
series_df.head()
# Out:
#            series_id                                        series_name
# 0     AG.AGR.TRAC.NO                   Agricultural machinery, tractors
# 1  AG.CON.FERT.PT.ZS  Fertilizer consumption (% of fertilizer produc...
# 2     AG.CON.FERT.ZS  Fertilizer consumption (kilograms per hectare ...
# 3     AG.LND.AGRI.K2                         Agricultural land (sq. km)
# 4     AG.LND.AGRI.ZS                 Agricultural land (% of land area)

# %%
# export to csv for review of WDI series(data streams) for review and decision of what should be included in ETL
series_df.to_csv('series_review.csv')

# %%
#create DataFrame that contains only the series(data streams) that will be loaded
series_list = ['EG.ELC.ACCS.ZS', 'EN.ATM.CO2E.PC', 'FX.OWN.TOTL.ZS', 'IC.BUS.DFRN.XQ', 'IC.FRM.BRIB.ZS', 'IC.LGL.CRED.XQ', 
    'IT.CEL.SETS.P2', 'LP.LPI.OVRL.XQ', 'MS.MIL.XPND.GD.ZS', 'NE.CON.PRVT.PC.KD', 'NY.GDP.PCAP.CD', 'NY.GDP.PCAP.KD.ZG',
    'SE.ADT.LITR.FE.ZS', 'SE.ADT.LITR.MA.ZS', 'SE.ADT.LITR.ZS', 'SE.PRM.CMPT.ZS', 'SE.SEC.CUAT.UP.ZS', 'SG.GEN.PARL.ZS',
    'SH.DYN.MORT', 'SH.STA.MMRT', 'SH.STA.SUIC.P5',	'SH.XPD.CHEX.GD.ZS', 'SH.XPD.GHED.GD.ZS', 'SH.XPD.PVTD.CH.ZS', 'SI.POV.GINI',
    'SL.EMP.TOTL.SP.ZS', 'SL.TLF.0714.ZS', 'SL.TLF.ACTI.ZS', 'SL.UEM.TOTL.ZS', 'SP.RUR.TOTL.ZS']
series_df_filter = series_df[series_df['series_id'].isin(series_list)]
series_df_filter
# Out:
#               series_id                                        series_name
# 201      EG.ELC.ACCS.ZS            Access to electricity (% of population)
# 229      EN.ATM.CO2E.PC             CO2 emissions (metric tons per capita)
# 338      FX.OWN.TOTL.ZS  Account ownership at a financial institution o...
# 395      IC.BUS.DFRN.XQ  Ease of doing business score (0 = lowest perfo...
# 414      IC.FRM.BRIB.ZS  Bribery incidence (% of firms experiencing at ...
# 434      IC.LGL.CRED.XQ  Strength of legal rights index (0=weak to 12=s...
# 512      IT.CEL.SETS.P2     Mobile cellular subscriptions (per 100 people)
# 526      LP.LPI.OVRL.XQ  Logistics performance index: Overall (1=low to...
# 534   MS.MIL.XPND.GD.ZS                    Military expenditure (% of GDP)
# 549   NE.CON.PRVT.PC.KD  Households and NPISHs Final consumption expend...
# 686      NY.GDP.PCAP.CD                       GDP per capita (current US$)
# 689   NY.GDP.PCAP.KD.ZG                   GDP per capita growth (annual %)
# 766   SE.ADT.LITR.FE.ZS  Literacy rate, adult female (% of females ages...
# 767   SE.ADT.LITR.MA.ZS  Literacy rate, adult male (% of males ages 15 ...
# 768      SE.ADT.LITR.ZS  Literacy rate, adult total (% of people ages 1...
# 785      SE.PRM.CMPT.ZS  Primary completion rate, total (% of relevant ...
# 844   SE.SEC.CUAT.UP.ZS  Educational attainment, at least completed upp...
# 911      SG.GEN.PARL.ZS  Proportion of seats held by women in national ...
# 946         SH.DYN.MORT    Mortality rate, under-5 (per 1,000 live births)
# 1012        SH.STA.MMRT  Maternal mortality ratio (modeled estimate, pe...
# 1035     SH.STA.SUIC.P5    Suicide mortality rate (per 100,000 population)
# 1061  SH.XPD.CHEX.GD.ZS              Current health expenditure (% of GDP)
# 1068  SH.XPD.GHED.GD.ZS  Domestic general government health expenditure...
# 1075  SH.XPD.PVTD.CH.ZS  Domestic private health expenditure (% of curr...
# 1088        SI.POV.GINI                                         Gini index
# 1132  SL.EMP.TOTL.SP.ZS  Employment to population ratio, 15+, total (%)...
# 1175     SL.TLF.0714.ZS  Children in employment, total (% of children a...
# 1184     SL.TLF.ACTI.ZS  Labor force participation rate, total (% of to...
# 1230     SL.UEM.TOTL.ZS  Unemployment, total (% of total labor force) (...
# 1337     SP.RUR.TOTL.ZS           Rural population (% of total population)

# %%
# Create API call to retrieve series (data streams) data. API call can't pass list of ids, run 5 at a time 
response1 = wb.data.DataFrame(['EG.ELC.ACCS.ZS', 'EN.ATM.CO2E.PC', 'FX.OWN.TOTL.ZS', 'IC.BUS.DFRN.XQ', 'IC.FRM.BRIB.ZS'], time = range(2018, 2021))
response2 = wb.data.DataFrame(['IC.LGL.CRED.XQ', 'IT.CEL.SETS.P2', 'LP.LPI.OVRL.XQ', 'MS.MIL.XPND.GD.ZS', 'NE.CON.PRVT.PC.KD'], time = range(2018, 2021))
response3 = wb.data.DataFrame(['NY.GDP.PCAP.CD', 'NY.GDP.PCAP.KD.ZG', 'SE.ADT.LITR.FE.ZS', 'SE.ADT.LITR.MA.ZS', 'SE.ADT.LITR.ZS'], time = range(2018, 2021))
response4 = wb.data.DataFrame(['SE.PRM.CMPT.ZS', 'SE.SEC.CUAT.UP.ZS', 'SG.GEN.PARL.ZS', 'SH.DYN.MORT', 'SH.STA.MMRT'], time = range(2018, 2021))
response5 = wb.data.DataFrame(['SH.STA.SUIC.P5',	'SH.XPD.CHEX.GD.ZS', 'SH.XPD.GHED.GD.ZS', 'SH.XPD.PVTD.CH.ZS', 'SI.POV.GINI'], time = range(2018, 2021))
response6 = wb.data.DataFrame(['SL.EMP.TOTL.SP.ZS', 'SL.TLF.0714.ZS', 'SL.TLF.ACTI.ZS', 'SL.UEM.TOTL.ZS', 'SP.RUR.TOTL.ZS'], time = range(2018, 2021))

# %%
# Concantenate responses into one Pandas series. Change to DataFrame. Correct dtypes
frames = [response1, response2, response3, response3, response4, response5, response6]
dextract = pd.concat(frames)
dextract_df = dextract.reset_index()
dextract_df = dextract_df.rename(columns={'economy':'country_code', 'series': 'series_id'})
dextract_df['country_code'] = dextract_df['country_code'].astype('string')
dextract_df['series_id'] = dextract_df['series_id'].astype('string')
dextract_df.dtypes
# Out:
# country_code     string
# series_id        string
# YR2018          float64
# YR2019          float64
# YR2020          float64
# dtype: object

# %%
# Add column with average of three years' data. Drop individual year columns. Drop NaN nad rename columns, change dtypes so objects are strings 
dtransform1_df = dextract_df
dtransform1_df['value'] = dtransform1_df[['YR2018','YR2019','YR2019']].mean(axis=1)
dtransform1_df = dtransform1_df.drop(columns=['YR2018','YR2019', 'YR2020'])
dtransform1_df = dtransform1_df.dropna()
dtransform1_df
# Out:
#      country_code          series_id       value
# 0             ABW     EG.ELC.ACCS.ZS  100.000000
# 5             AFE     EG.ELC.ACCS.ZS   43.867866
# 6             AFE     EN.ATM.CO2E.PC    0.914914
# 8             AFE     IC.BUS.DFRN.XQ   53.332704
# 10            AFG     EG.ELC.ACCS.ZS   97.338710
# ...           ...                ...         ...
# 9304          ZMB     SP.RUR.TOTL.ZS   56.111667
# 9305          ZWE  SL.EMP.TOTL.SP.ZS   80.415332
# 9307          ZWE     SL.TLF.ACTI.ZS   83.976667
# 9308          ZWE     SL.UEM.TOTL.ZS    4.820667
# 9309          ZWE     SP.RUR.TOTL.ZS   67.790333
#
# [6393 rows x 3 columns]

# %%
# Merge series DataFrame with Transform DataFrame on series_name and drop series-id
dtransform2_df = dtransform1_df.merge(series_df_filter, how = 'left', on = 'series_id')
dtransform2_df = dtransform2_df.drop(['series_id'], axis=1)
dtransform2_df = dtransform2_df[['country_code', 'series_name','value']]
dtransform2_df.head()
# Out:
#   country_code                                        series_name       value
# 0          ABW            Access to electricity (% of population)  100.000000
# 1          AFE            Access to electricity (% of population)   43.867866
# 2          AFE             CO2 emissions (metric tons per capita)    0.914914
# 3          AFE  Ease of doing business score (0 = lowest perfo...   53.332704
# 4          AFG            Access to electricity (% of population)   97.338710

# %%
# Transpose DataFrame
dtransform3_df = dtransform2_df
dtransform3_df = dtransform3_df.pivot_table(values='value', index = 'country_code', columns = 'series_name')
dtransform3_df.head()
# Out:
# series_name   Access to electricity (% of population)  \
# country_code
# ABW                                        100.000000
# AFE                                         43.867866
# AFG                                         97.338710
# AFW                                         51.280033
# AGO                                         45.525200
#
# series_name   Bribery incidence (% of firms experiencing at least one bribe payment request)  \
# country_code
# ABW                                                         NaN
# AFE                                                         NaN
# AFG                                                         NaN
# AFW                                                         NaN
# AGO                                                         NaN
#
# series_name   CO2 emissions (metric tons per capita)  \
# country_code
# ABW                                              NaN
# AFE                                         0.914914
# AFG                                         0.160981
# AFW                                         0.491434
# AGO                                         0.787316
#
# series_name   Current health expenditure (% of GDP)  \
# country_code
# ABW                                             NaN
# AFE                                        6.273200
# AFG                                       13.537049
# AFW                                        3.375120
# AGO                                        2.535607
#
# series_name   Domestic general government health expenditure (% of GDP)  \
# country_code
# ABW                                                         NaN
# AFE                                                    3.032919
# AFG                                                    0.906027
# AFW                                                    0.744711
# AGO                                                    1.052493
#
# series_name   Domestic private health expenditure (% of current health expenditure)  \
# country_code
# ABW                                                         NaN
# AFE                                                   39.948103
# AFG                                                   78.372658
# AFW                                                   65.022605
# AGO                                                   55.266846
#
# series_name   Ease of doing business score (0 = lowest performance to 100 = best performance)  \
# country_code
# ABW                                                         NaN
# AFE                                                   53.332704
# AFG                                                   44.111123
# AFW                                                   49.372293
# AGO                                                   41.259603
#
# series_name   Educational attainment, at least completed upper secondary, population 25+, total (%) (cumulative)  \
# country_code
# ABW                                                         NaN
# AFE                                                         NaN
# AFG                                                         NaN
# AFW                                                         NaN
# AGO                                                         NaN
#
# series_name   Employment to population ratio, 15+, total (%) (modeled ILO estimate)  \
# country_code
# ABW                                                         NaN
# AFE                                                   66.512569
# AFG                                                   42.110332
# AFW                                                   56.688298
# AGO                                                   71.495000
#
# series_name   GDP per capita (current US$)  ...  \
# country_code                                ...
# ABW                           30841.827649  ...
# AFE                            1521.216726  ...
# AFG                             491.342373  ...
# AFW                            1753.280448  ...
# AGO                            2293.513504  ...
#
# series_name   Logistics performance index: Overall (1=low to 5=high)  \
# country_code
# ABW                                                         NaN
# AFE                                                    2.492222
# AFG                                                    1.950000
# AFW                                                    2.413333
# AGO                                                    2.050000
#
# series_name   Military expenditure (% of GDP)  \
# country_code
# ABW                                       NaN
# AFE                                  1.121499
# AFG                                  1.081069
# AFW                                  0.887280
# AGO                                  1.719752
#
# series_name   Mobile cellular subscriptions (per 100 people)  \
# country_code
# ABW                                               132.625995
# AFE                                                70.647443
# AFG                                                59.277629
# AFW                                                94.497284
# AGO                                                45.442598
#
# series_name   Mortality rate, under-5 (per 1,000 live births)  \
# country_code
# ABW                                                       NaN
# AFE                                                 60.727079
# AFG                                                 60.833333
# AFW                                                 97.426573
# AGO                                                 75.233333
#
# series_name   Primary completion rate, total (% of relevant age group)  \
# country_code
# ABW                                                         NaN
# AFE                                                         NaN
# AFG                                                   84.762169
# AFW                                                         NaN
# AGO                                                         NaN
#
# series_name   Proportion of seats held by women in national parliaments (%)  \
# country_code
# ABW                                                         NaN
# AFE                                                   29.106899
# AFG                                                   27.868852
# AFW                                                   15.372006
# AGO                                                   30.151515
#
# series_name   Rural population (% of total population)  \
# country_code
# ABW                                          56.499000
# AFE                                          63.869862
# AFG                                          74.332333
# AFW                                          52.960385
# AGO                                          34.044000
#
# series_name   Strength of legal rights index (0=weak to 12=strong)  \
# country_code
# ABW                                                         NaN
# AFE                                                    4.538462
# AFG                                                   10.000000
# AFW                                                    5.863636
# AGO                                                    1.000000
#
# series_name   Suicide mortality rate (per 100,000 population)  \
# country_code
# ABW                                                       NaN
# AFE                                                  8.067157
# AFG                                                  4.100000
# AFW                                                  5.416273
# AGO                                                  6.066667
#
# series_name   Unemployment, total (% of total labor force) (modeled ILO estimate)
# country_code
# ABW                                                         NaN
# AFE                                                    6.853290
# AFG                                                   11.195333
# AFW                                                    6.055939
# AGO                                                    7.421000
#
# [5 rows x 27 columns]

# %%
# remove multiindex
dtransform3_df = dtransform3_df.rename_axis(None)
dtransform3_df.reset_index(inplace=True)
# dtransform3_df = dtransform3_df.rename({'series_name': 'country_code'})
# dtransform3_df.to_csv('WDI.csv')
dtransform3_df.head()
# Out:
# series_name index  Access to electricity (% of population)  \
# 0             ABW                               100.000000
# 1             AFE                                43.867866
# 2             AFG                                97.338710
# 3             AFW                                51.280033
# 4             AGO                                45.525200
#
# series_name  Bribery incidence (% of firms experiencing at least one bribe payment request)  \
# 0                                                          NaN
# 1                                                          NaN
# 2                                                          NaN
# 3                                                          NaN
# 4                                                          NaN
#
# series_name  CO2 emissions (metric tons per capita)  \
# 0                                               NaN
# 1                                          0.914914
# 2                                          0.160981
# 3                                          0.491434
# 4                                          0.787316
#
# series_name  Current health expenditure (% of GDP)  \
# 0                                              NaN
# 1                                         6.273200
# 2                                        13.537049
# 3                                         3.375120
# 4                                         2.535607
#
# series_name  Domestic general government health expenditure (% of GDP)  \
# 0                                                          NaN
# 1                                                     3.032919
# 2                                                     0.906027
# 3                                                     0.744711
# 4                                                     1.052493
#
# series_name  Domestic private health expenditure (% of current health expenditure)  \
# 0                                                          NaN
# 1                                                    39.948103
# 2                                                    78.372658
# 3                                                    65.022605
# 4                                                    55.266846
#
# series_name  Ease of doing business score (0 = lowest performance to 100 = best performance)  \
# 0                                                          NaN
# 1                                                    53.332704
# 2                                                    44.111123
# 3                                                    49.372293
# 4                                                    41.259603
#
# series_name  Educational attainment, at least completed upper secondary, population 25+, total (%) (cumulative)  \
# 0                                                          NaN
# 1                                                          NaN
# 2                                                          NaN
# 3                                                          NaN
# 4                                                          NaN
#
# series_name  Employment to population ratio, 15+, total (%) (modeled ILO estimate)  \
# 0                                                          NaN
# 1                                                    66.512569
# 2                                                    42.110332
# 3                                                    56.688298
# 4                                                    71.495000
#
# series_name  ...  Logistics performance index: Overall (1=low to 5=high)  \
# 0            ...                                                NaN
# 1            ...                                           2.492222
# 2            ...                                           1.950000
# 3            ...                                           2.413333
# 4            ...                                           2.050000
#
# series_name  Military expenditure (% of GDP)  \
# 0                                        NaN
# 1                                   1.121499
# 2                                   1.081069
# 3                                   0.887280
# 4                                   1.719752
#
# series_name  Mobile cellular subscriptions (per 100 people)  \
# 0                                                132.625995
# 1                                                 70.647443
# 2                                                 59.277629
# 3                                                 94.497284
# 4                                                 45.442598
#
# series_name  Mortality rate, under-5 (per 1,000 live births)  \
# 0                                                        NaN
# 1                                                  60.727079
# 2                                                  60.833333
# 3                                                  97.426573
# 4                                                  75.233333
#
# series_name  Primary completion rate, total (% of relevant age group)  \
# 0                                                          NaN
# 1                                                          NaN
# 2                                                    84.762169
# 3                                                          NaN
# 4                                                          NaN
#
# series_name  Proportion of seats held by women in national parliaments (%)  \
# 0                                                          NaN
# 1                                                    29.106899
# 2                                                    27.868852
# 3                                                    15.372006
# 4                                                    30.151515
#
# series_name  Rural population (% of total population)  \
# 0                                           56.499000
# 1                                           63.869862
# 2                                           74.332333
# 3                                           52.960385
# 4                                           34.044000
#
# series_name  Strength of legal rights index (0=weak to 12=strong)  \
# 0                                                          NaN
# 1                                                     4.538462
# 2                                                    10.000000
# 3                                                     5.863636
# 4                                                     1.000000
#
# series_name  Suicide mortality rate (per 100,000 population)  \
# 0                                                        NaN
# 1                                                   8.067157
# 2                                                   4.100000
# 3                                                   5.416273
# 4                                                   6.066667
#
# series_name  Unemployment, total (% of total labor force) (modeled ILO estimate)
# 0                                                          NaN
# 1                                                     6.853290
# 2                                                    11.195333
# 3                                                     6.055939
# 4                                                     7.421000
#
# [5 rows x 28 columns]

# %%
# rename columns
dtransform3_df.columns = ['counry_code', "Access_to_electricity", "Bribery_incidence", "CO2_emissions", "Current_health_expenditure",
    "Government_health_expenditure", "Private_health_expenditure", "Ease_of_Doing_Business", "Completed_Secondary_Education",
    "Employemnt_to_population", "GDP_per_capital", "GDP_per_capita_growth", "Gini", "Household_consumption_per_capital",
    "Labor_force_participation", "Literacy_rate_Female", "Literacy_rate_Male", "Literacy_rate_total", "Logistics_index",
    "Military_expenditure", "Cellular_subscription_per_one_humdred", "Mortality_rate_under_five", "Completed_primary_education", "Proportion_of_women_in_parliament",    "Percent_rural_population", "Strenth_of_legal_rights", "Suicide_rate", "Unemployment"]
dtransform3_df.head()
# Out:
#   counry_code  Access_to_electricity  Bribery_incidence  CO2_emissions  \
# 0         ABW             100.000000                NaN            NaN
# 1         AFE              43.867866                NaN       0.914914
# 2         AFG              97.338710                NaN       0.160981
# 3         AFW              51.280033                NaN       0.491434
# 4         AGO              45.525200                NaN       0.787316
#
#    Current_health_expenditure  Government_health_expenditure  \
# 0                         NaN                            NaN
# 1                    6.273200                       3.032919
# 2                   13.537049                       0.906027
# 3                    3.375120                       0.744711
# 4                    2.535607                       1.052493
#
#    Private_health_expenditure  Ease_of_Doing_Business  \
# 0                         NaN                     NaN
# 1                   39.948103               53.332704
# 2                   78.372658               44.111123
# 3                   65.022605               49.372293
# 4                   55.266846               41.259603
#
#    Completed_Secondary_Education  Employemnt_to_population  ...  \
# 0                            NaN                       NaN  ...
# 1                            NaN                 66.512569  ...
# 2                            NaN                 42.110332  ...
# 3                            NaN                 56.688298  ...
# 4                            NaN                 71.495000  ...
#
#    Logistics_index  Military_expenditure  \
# 0              NaN                   NaN
# 1         2.492222              1.121499
# 2         1.950000              1.081069
# 3         2.413333              0.887280
# 4         2.050000              1.719752
#
#    Cellular_subscription_per_one_humdred  Mortality_rate_under_five  \
# 0                             132.625995                        NaN
# 1                              70.647443                  60.727079
# 2                              59.277629                  60.833333
# 3                              94.497284                  97.426573
# 4                              45.442598                  75.233333
#
#    Completed_primary_education  Proportion_of_women_in_parliament  \
# 0                          NaN                                NaN
# 1                          NaN                          29.106899
# 2                    84.762169                          27.868852
# 3                          NaN                          15.372006
# 4                          NaN                          30.151515
#
#    Percent_rural_population  Strenth_of_legal_rights  Suicide_rate  \
# 0                 56.499000                      NaN           NaN
# 1                 63.869862                 4.538462      8.067157
# 2                 74.332333                10.000000      4.100000
# 3                 52.960385                 5.863636      5.416273
# 4                 34.044000                 1.000000      6.066667
#
#    Unemployment
# 0           NaN
# 1      6.853290
# 2     11.195333
# 3      6.055939
# 4      7.421000
#
# [5 rows x 28 columns]

# %%
# inner join to drop countries not in happiness index
countries = pd.read_csv("countires.csv")
dtransform3_df = dtransform3_df.merge(countries, how = 'inner', on='country_code',)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13044\1700208503.py in <module>
#       1 # inner join to drop countries not in happiness index
#       2 countries = pd.read_csv("countires.csv")
# ----> 3 dtransform3_df = dtransform3_df.merge(countries, how = 'inner', on='country_code',)
#
# c:\Users\elott\anaconda3\envs\PythonDataOne\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7295             copy=copy,
#    7296             indicator=indicator,
# -> 7297             validate=validate,
#    7298         )
#    7299
#
# c:\Users\elott\anaconda3\envs\PythonDataOne\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      84         copy=copy,
#      85         indicator=indicator,
# ---> 86         validate=validate,
#      87     )
#      88     return op.get_result()
#
# c:\Users\elott\anaconda3\envs\PythonDataOne\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     625             self.right_join_keys,
#     626             self.join_names,
# --> 627         ) = self._get_merge_keys()
#     628
#     629         # validate the merge keys dtypes. We may need to coerce
#
# c:\Users\elott\anaconda3\envs\PythonDataOne\lib\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#     994                         right_keys.append(rk)
#     995                     if lk is not None:
# --> 996                         left_keys.append(left._get_label_or_level_values(lk))
#     997                         join_names.append(lk)
#     998                     else:
#
# c:\Users\elott\anaconda3\envs\PythonDataOne\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1690             values = self.axes[axis].get_level_values(key)._values
#    1691         else:
# -> 1692             raise KeyError(key)
#    1693
#    1694         # Check for duplicates
#
# KeyError: 'country_code'
