# %%
#Bringing in CSVs use in data compilation 
import pandas as pd
from sqlalchemy import create_engine, Column, Integer, String
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()
engine = create_engine('sqlite:///HappinessIndex.sqlite')
#Base.metadata.drop_all(engine)

# %%
from sqlalchemy import Float

# %%
#Reading in the World Happiness Report from 2021
happiness = pd.read_csv("Data/world-happiness-report-2021.csv")
happiness
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
#Reading in the ISO codes for each country
isocc = pd.read_csv("Data/iso-country-codes.csv")
isocc
# Out:
#           Country name Alpha-2 code Alpha-3 code  Numeric code     ISO 3166-2
# 0          Afghanistan           AF          AFG             4  ISO 3166-2:AF
# 1        Åland Islands           AX          ALA           248  ISO 3166-2:AX
# 2              Albania           AL          ALB             8  ISO 3166-2:AL
# 3              Algeria           DZ          DZA            12  ISO 3166-2:DZ
# 4       American Samoa           AS          ASM            16  ISO 3166-2:AS
# ..                 ...          ...          ...           ...            ...
# 241  Wallis and Futuna           WF          WLF           876  ISO 3166-2:WF
# 242     Western Sahara           EH          ESH           732  ISO 3166-2:EH
# 243              Yemen           YE          YEM           887  ISO 3166-2:YE
# 244             Zambia           ZM          ZMB           894  ISO 3166-2:ZM
# 245           Zimbabwe           ZW          ZWE           716  ISO 3166-2:ZW
#
# [246 rows x 5 columns]

# %%
#Combining the World Happiness Report & the ISOs 
Happiness_ISO = pd.merge(left=happiness,right=isocc, left_on='Country name', right_on='Country name')
Happiness_ISO.shape
Happiness_ISO
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 130      Lesotho  Sub-Saharan Africa         3.512
# 131     Botswana  Sub-Saharan Africa         3.467
# 132       Rwanda  Sub-Saharan Africa         3.415
# 133     Zimbabwe  Sub-Saharan Africa         3.145
# 134  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
#Dropping the 2 code, ISO#, & numberic codes since those aren't needed to combine with our data

Happiness_ISO.drop(['Regional indicator','Alpha-2 code', 'Numeric code','ISO 3166-2','Standard error of ladder score','upperwhisker','lowerwhisker'], axis='columns', inplace=True)
Happiness_ISO
# Out:
#     Country name  Ladder score  Logged GDP per capita  Social support  \
# 0        Finland         7.842                 10.775           0.954
# 1        Denmark         7.620                 10.933           0.954
# 2    Switzerland         7.571                 11.117           0.942
# 3        Iceland         7.554                 10.878           0.983
# 4    Netherlands         7.464                 10.932           0.942
# ..           ...           ...                    ...             ...
# 130      Lesotho         3.512                  7.926           0.787
# 131     Botswana         3.467                  9.782           0.784
# 132       Rwanda         3.415                  7.676           0.552
# 133     Zimbabwe         3.145                  7.943           0.750
# 134  Afghanistan         2.523                  7.695           0.463
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# ...

# %%
Happiness_ISO = Happiness_ISO.rename(columns={'Alpha-3 code': 'country_code'})
Happiness_ISO.set_index('country_code', inplace=True)
Happiness_ISO
# Out:
#              Country name  Ladder score  Logged GDP per capita  \
# country_code
# FIN               Finland         7.842                 10.775
# DNK               Denmark         7.620                 10.933
# CHE           Switzerland         7.571                 11.117
# ISL               Iceland         7.554                 10.878
# NLD           Netherlands         7.464                 10.932
# ...                   ...           ...                    ...
# LSO               Lesotho         3.512                  7.926
# BWA              Botswana         3.467                  9.782
# RWA                Rwanda         3.415                  7.676
# ZWE              Zimbabwe         3.145                  7.943
# AFG           Afghanistan         2.523                  7.695
#
#               Social support  Healthy life expectancy  \
# country_code
# FIN                    0.954                   72.000
# DNK                    0.954                   72.700
# ...

# %%
#During discussions we decided that we didn't need all of the Happiness Report data along with the alpha-3 because we are using it for joining table. Ugly & inefficient, but we go there.
countries_df=Happiness_ISO.drop(['Ladder score', 'Logged GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption', 'Ladder score in Dystopia', 'Explained by: Log GDP per capita', 'Explained by: Social support', 'Explained by: Healthy life expectancy', 'Explained by: Freedom to make life choices', 'Explained by: Generosity', 'Explained by: Perceptions of corruption', 'Dystopia + residual'], axis='columns')
countries_df.rename(columns={'Country name':'country_name'}, inplace=True)
countries_df
# Out:
#              country_name
# country_code
# FIN               Finland
# DNK               Denmark
# CHE           Switzerland
# ISL               Iceland
# NLD           Netherlands
# ...                   ...
# LSO               Lesotho
# BWA              Botswana
# RWA                Rwanda
# ZWE              Zimbabwe
# AFG           Afghanistan
#
# [135 rows x 1 columns]

# %%
Happiness_Index=Happiness_ISO.drop(['Country name'], axis='columns')
Happiness_Index.rename(columns={'Dystopia + residual':'Dystopia_residual','Explained by: Log GDP per capita':'Explained by Log GDP per capita','Explained by: Social support':'Explained by Social support','Explained by: Healthy life expectancy':'Explained by Healthy life expectancy','Explained by: Freedom to make life choices':'Explained by Freedom to make life choices','Explained by: Generosity':'Explained by Generosity','Explained by: Perceptions of corruption':'Explained by Perceptions of corruption'}, inplace=True)
Happiness_Index
# Out:
#               Ladder score  Logged GDP per capita  Social support  \
# country_code
# FIN                  7.842                 10.775           0.954
# DNK                  7.620                 10.933           0.954
# CHE                  7.571                 11.117           0.942
# ISL                  7.554                 10.878           0.983
# NLD                  7.464                 10.932           0.942
# ...                    ...                    ...             ...
# LSO                  3.512                  7.926           0.787
# BWA                  3.467                  9.782           0.784
# RWA                  3.415                  7.676           0.552
# ZWE                  3.145                  7.943           0.750
# AFG                  2.523                  7.695           0.463
#
#               Healthy life expectancy  Freedom to make life choices  \
# country_code
# FIN                            72.000                         0.949
# ...

# %%
#A CSV of the original Happiness Report + ISO was created called Happiness_Report_ISO but that won't be used. 
Happiness_ISO.to_csv('Country_with_ISO.csv')

# %%
# Define our country table
class HappinessIndex(Base):
    __tablename__ = 'countries'
    __table_args__ = {'extend_existing': True}
    country_code = Column(String, primary_key=True)
    country_name = Column(String)

# %%
class Happiness_Index(Base):
    __tablename__ = 'Happiness_Index'
    __table_args__ = {'extend_existing': True}
    country_code = Column(String, primary_key=True)
    Ladder_score = Column(String)
    Logged_GDP_per_capita = Column(Float)
    Social_support = Column(Float)
    Healthy_life_expectancy = Column(Float)
    Freedom_to_make_life_choices = Column(Float)
    Generosity = Column(Float)
    Perceptions_of_corruption = Column(Float)
    Ladder_score_in_Dystopia = Column(Float)
    Explained_by_Log_GDP_per_capita = Column(Float)
    Explained_by_Social_support = Column(Float)
    Explained_by_Healthy_life_expectancy = Column(Float)
    Explained_by_Freedom_to_make_life_choices = Column(Float)
    Explained_by_Generosity = Column(Float)
    Explained_by_Perceptions_of_corruption = Column(Float)
    Dystopia_residual = Column(Float)

# %%
Base.metadata.tables
# Out:
# FacadeDict({'countries': Table('countries', MetaData(), Column('country_code', String(), table=<countries>, primary_key=True, nullable=False), Column('country_name', String(), table=<countries>), schema=None), 'Happiness_Index': Table('Happiness_Index', MetaData(), Column('country_code', String(), table=<Happiness_Index>, primary_key=True, nullable=False), Column('Ladder_score', String(), table=<Happiness_Index>), Column('Logged_GDP_per_capita', Float(), table=<Happiness_Index>), Column('Social_support', Float(), table=<Happiness_Index>), Column('Healthy_life_expectancy', Float(), table=<Happiness_Index>), Column('Freedom_to_make_life_choices', Float(), table=<Happiness_Index>), Column('Generosity', Float(), table=<Happiness_Index>), Column('Perceptions_of_corruption', Float(), table=<Happiness_Index>), Column('Ladder_score_in_Dystopia', Float(), table=<Happiness_Index>), Column('Explained_by_Log_GDP_per_capita', Float(), table=<Happiness_Index>), Column('Explained_by_Social_support'
# ...

# %%
Base.metadata.create_all(engine)

# %%
countries_df.to_sql('countries',engine, if_exists='append')
#pandas.DataFrame.to_sql(table_name, engine_name, if_exists, schema, index, chunksize, dtype)
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# c:\Users\tkg37kk\.conda\envs\Pythondata\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1880                     self.dialect.do_executemany(
# -> 1881                         cursor, statement, parameters, context
#    1882                     )
#
# c:\Users\tkg37kk\.conda\envs\Pythondata\lib\site-packages\sqlalchemy\engine\default.py in do_executemany(self, cursor, statement, parameters, context)
#     732     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 733         cursor.executemany(statement, parameters)
#     734
#
# IntegrityError: UNIQUE constraint failed: countries.country_code
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
Happiness_Index.to_sql('Happiness_Index',engine, if_exists='append')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-f4bd051da634> in <module>
# ----> 1 Happiness_Index.to_sql('Happiness_Index',engine, if_exists='append')
#
# AttributeError: type object 'Happiness_Index' has no attribute 'to_sql'
